# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("clean_customer_churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
print(df.shape)
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe(include="all")
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7043.000000    7043       7043  7043.000000
# unique        7043      2            NaN       2          2          NaN
# top     7590-VHVEG   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.162147     NaN        NaN    32.371149
# std            NaN    NaN       0.368612     NaN        NaN    24.559481
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="Churn", data=df)

plt.title("Customer Churn Distribution")

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="gender", hue="Churn", data=df)

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="SeniorCitizen", hue="Churn", data=df)

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="Partner", hue="Churn", data=df)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(x="Contract", hue="Churn", data=df)

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(x="PaymentMethod", hue="Churn", data=df)

plt.xticks(rotation=20)

plt.show()

# %%
plt.figure(figsize=(7,4))

sns.countplot(x="InternetService", hue="Churn", data=df)

plt.show()

# %%
plt.figure(figsize=(7,4))

sns.histplot(df["MonthlyCharges"], bins=30, kde=True)

plt.show()

# %%
plt.figure(figsize=(7,4))

sns.histplot(df["TotalCharges"], bins=30, kde=True)

plt.show()

# %%
plt.figure(figsize=(7,4))

sns.histplot(df["tenure"], bins=30, kde=True)

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.boxplot(x="Churn", y="MonthlyCharges", data=df)

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.boxplot(x="Churn", y="tenure", data=df)

plt.show()

# %%
numeric = df.select_dtypes(include=["int64","float64"])

plt.figure(figsize=(10,6))

sns.heatmap(numeric.corr(), annot=True, cmap="coolwarm")

plt.show()

# %%
churn = df["Churn"].value_counts(normalize=True) * 100

print(churn)
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
print(df.groupby("Churn")["MonthlyCharges"].mean())
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
print(df.groupby("Churn")["tenure"].mean())
# Out:
# Churn
# No     37.569965
# Yes    17.979133
# Name: tenure, dtype: float64

# %%
print("="*60)
print("BUSINESS INSIGHTS")
print("="*60)

print("1. Customers with Month-to-Month contracts are more likely to churn.")
print("2. Customers with higher monthly charges tend to leave more frequently.")
print("3. Long-tenure customers are more loyal.")
print("4. Fiber Optic internet users show relatively higher churn.")
print("5. Electronic Check users have a higher churn rate.")
# Out:
# ...
# BUSINESS INSIGHTS
# ...
# 1. Customers with Month-to-Month contracts are more likely to churn.
# 2. Customers with higher monthly charges tend to leave more frequently.
# 3. Long-tenure customers are more loyal.
# 4. Fiber Optic internet users show relatively higher churn.
# 5. Electronic Check users have a higher churn rate.

# %%
print("="*60)
print("BUSINESS RECOMMENDATIONS")
print("="*60)

print("1. Offer long-term contract discounts.")
print("2. Reward loyal customers.")
print("3. Reduce churn through personalized offers.")
print("4. Improve service quality for Fiber Optic users.")
print("5. Launch retention campaigns for high-risk customers.")
# Out:
# ...
# BUSINESS RECOMMENDATIONS
# ...
# 1. Offer long-term contract discounts.
# 2. Reward loyal customers.
# 3. Reduce churn through personalized offers.
# 4. Improve service quality for Fiber Optic users.
# 5. Launch retention campaigns for high-risk customers.

# %%
print("="*60)
print("PROJECT CONCLUSION")
print("="*60)

print("""
Exploratory Data Analysis was performed on the Customer Churn dataset.

Several important trends, customer behaviors, and churn patterns were identified.

The insights generated from this analysis can help businesses improve
customer retention strategies and make better business decisions.

The cleaned dataset is now ready for Machine Learning and advanced analytics.
""")
# Out:
# ...
# PROJECT CONCLUSION
# ...
#
# Exploratory Data Analysis was performed on the Customer Churn dataset.
#
# Several important trends, customer behaviors, and churn patterns were identified.
#
# The insights generated from this analysis can help businesses improve
# customer retention strategies and make better business decisions.
#
# The cleaned dataset is now ready for Machine Learning and advanced analytics.
